# %% [markdown]
# # Iris

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# set the graphs to show in the jupyter notebook
# %matplotlib inline

# set seaborn graphs to a better style
sns.set(style="ticks")

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

attributes = ["sepal_length", "sepal_width", "petal_length", "petal_width", "class"]
iris = pd.read_csv(url, names = attributes)
iris.columns = attributes



iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

iris.columns = ['sepal_length','sepal_width', 'petal_length', 'petal_width', 'class']
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
pd.isnull(iris).sum()
# nice no missing value
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.iloc[10:30,2:3] = np.nan
iris.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           NaN          0.2  Iris-setosa
# 11           4.8          3.4           NaN          0.2  Iris-setosa
# ...

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris.petal_length.fillna(1, inplace = True)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.iloc[0:3 ,:] = np.nan
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           NaN          NaN           NaN          NaN          NaN
# 1           NaN          NaN           NaN          NaN          NaN
# 2           NaN          NaN           NaN          NaN          NaN
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris = iris.dropna(how='any')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris = iris.reset_index(drop = True)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.6          3.1           1.5          0.2  Iris-setosa
# 1           5.0          3.6           1.4          0.2  Iris-setosa
# 2           5.4          3.9           1.7          0.4  Iris-setosa
# 3           4.6          3.4           1.4          0.3  Iris-setosa
# 4           5.0          3.4           1.5          0.2  Iris-setosa

# %% [markdown]
# #  w3resource:Question from each category and answers.

# %% [markdown]
# ### Basic - Iris flower data set
# #### 1. Write a Python program to load the iris data from a given csv file into a dataframe and print the shape of the data, type of the data and first 3 rows. Go to the editor

# %% [markdown]
#  Shape,type and first three rows

# %%
iris.shape
# Out:
# (147, 5)

# %%
iris.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.6          3.1           1.5          0.2  Iris-setosa
# 1           5.0          3.6           1.4          0.2  Iris-setosa
# 2           5.4          3.9           1.7          0.4  Iris-setosa

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Visualization - Iris flower data set

# %% [markdown]
# #### 1. Write a Python program to create a plot to get a general Statistics of Iris data.

# %%
iris.plot(kind = "area",fontsize=14, figsize = (13,8),colormap="gist_rainbow")  
plt.xlabel('Statistics',)
plt.ylabel('Value')
plt.title("General Statistics of Iris Dataset")
plt.show()

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    147.000000   147.000000    147.000000   147.000000
# mean       5.862585     3.050340      3.741497     1.219048
# std        0.824971     0.436263      1.840520     0.757278
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.500000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
#  ### K-Nearest Neighbors Algorithm in Iris flower data set

# %% [markdown]
# ####  2. Write a Python program using Scikit-learn to split the iris dataset into 70% train data and 30% test data. Out of total 150 records, the training set will contain 120 records and the test set contains 30 of those records. Print both datasets.

# %%
data = iris.values
X, y = data[:, :-1], data[:,-1]
print(X.shape, y.shape)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
print(X_train,y_train,X_test,y_test)
# Out:
# (147, 4) (147,)
# [[5.8 2.7 4.1 1.0]
#  [5.8 2.7 5.1 1.9]
#  [5.7 3.8 1.0 0.3]
#  [5.9 3.0 5.1 1.8]
#  [5.9 3.0 4.2 1.5]
#  [6.0 2.2 5.0 1.5]
#  [6.2 3.4 5.4 2.3]
#  [4.4 2.9 1.4 0.2]
#  [4.5 2.3 1.3 0.3]
#  [6.5 3.2 5.1 2.0]
#  [6.1 2.9 4.7 1.4]
#  [5.8 2.7 5.1 1.9]
#  [6.7 3.1 4.4 1.4]
#  [5.6 2.7 4.2 1.3]
#  [5.7 2.9 4.2 1.3]
#  [6.4 3.2 5.3 2.3]
#  [6.8 3.0 5.5 2.1]
#  [4.9 2.5 4.5 1.7]
#  [6.0 3.4 4.5 1.6]
#  [5.0 3.5 1.3 0.3]
#  [7.3 2.9 6.3 1.8]
#  [6.1 2.6 5.6 1.4]
#  [5.2 4.1 1.5 0.1]
#  [4.6 3.6 1.0 0.2]
#  [5.2 2.7 3.9 1.4]
#  [5.5 2.5 4.0 1.3]
#  [5.0 3.0 1.0 0.2]
#  [6.8 3.2 5.9 2.3]
#  [6.3 3.4 5.6 2.4]
#  [6.4 3.1 5.5 1.8]
#  [4.8 3.4 1.0 0.2]
#  [5.2 3.4 1.0 0.2]
#  [4.6 3.4 1.4 0.3]
#  [6.0 2.2 4.0 1.0]
#  [6.7 3.3 5.7 2.5]
#  [6.5 3.0 5.5 1.8]
#  [6.9 3.1 4.9 1.5]
#  [5.8 2.8 5.1 2.4]
#  [5.1 3.8 1.9 0.4]
#  [4.4 3.0 1.3 0.2]
#  [6.6 2.9 4.6 1.3]
#  [4.3 3.0 1.0 0.1]
#  [4.4 3.2 1.3 0.2]
#  [6.3 2.3 4.4 1.3]
#  [6.4 2.9 4.3 1.3]
#  [5.8 4.0 1.0 0.2]
# ...

# %% [markdown]
# ### Logistic Regression in Sci-Kit Learn

# %% [markdown]
# #### 1. Write a Python program to view some basic statistical details like percentile, mean, std etc. of the species of 'Iris-setosa', 'Iris-versicolor' and 'Iris-versicolor'.

# %%
iris.groupby('class').size()
# Out:
# class
# Iris-setosa        47
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
iris['class'].describe()
# Out:
# count                147
# unique                 3
# top       Iris-virginica
# freq                  50
# Name: class, dtype: object

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    147.000000   147.000000    147.000000   147.000000
# mean       5.862585     3.050340      3.741497     1.219048
# std        0.824971     0.436263      1.840520     0.757278
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.500000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
