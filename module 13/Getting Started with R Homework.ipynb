# %% [markdown]
# # How To Install R on a [Mac or Windows]

# %% [markdown]
# ### In this documentation we will cover how to

# %% [markdown]
# **  Install Anaconda → Install R → Install R studio **

# %% [markdown]
# #### Install Anaconda

# %% [markdown]
# #### 1. What is Anaconda?

# %% [markdown]
# **Anaconda free open source is helpful in distributing both Python and R programming language. Anaconda is widely used in the scientific community and data scientist to carry out Machine Learning project or data analysis.**

# %% [markdown]
# #### 2.What is an IDE?

# %% [markdown]
# **An integrated development environment (IDE) is software for building applications that combines common developer tools into a single graphical user interface (GUI).RStudio is an integrated development environment (IDE) for R. It includes a console, syntax-highlighting editor that supports direct code execution, as well as tools for plotting, history, debugging and workspace management.**

# %% [markdown]
# #### 3. Why use Anaconda?

# %% [markdown]
# **Anaconda is popular because it brings many of the tools used in data science and machine learning with just one install, so it's great for having short and simple setup. Like Virtualenv, Anaconda also uses the concept of creating environments so as to isolate different libraries and versions'
# Anaconda will help you to manage all the libraries required for Python, or R and install all the required libraries and IDE into one single folder to simplify package management.**

# %% [markdown]
# #### Install R

# %% [markdown]
# #### 1. What is R

# %% [markdown]
# **R is a programming language and free software developed by Ross Ihaka and Robert Gentleman in 1993.The primary uses of R is and will always be, statistic, visualization, and machine learning.**

# %% [markdown]
# #### 2.Who uses R?

# %% [markdown]
# **R is a programming language is widely used by data scientists and major corporations like Google, Airbnb, Facebook etc. for data analysis.If we break down the use of R by industry, we see that academics come first. R is a language to do statistic. R is the first choice in the healthcare industry, followed by government and consulting.**

# %% [markdown]
# #### 3.How is R different from python?

# %% [markdown]
#   **R and Python are both open-source programming languages with a large community. R is mainly used for statistical analysis while Python provides a more general approach to data science.There are around 12000 packages available in CRAN (open-source repository).The rich variety of library makes R the first choice for statistical analysis, especially for specialized analytical work.**
#     **The cutting-edge difference between R and the other statistical products is the output. R has fantastic tools to communicate the results. Rstudio comes with the library knitr which makesreporting trivial and elegant.**

# %% [markdown]
# #### Install R Studio

# %% [markdown]
# #### 1. What is R Studio?

# %% [markdown]
# **RStudio is an integrated development environment for R, a programming language for statistical computing and graphics. It is available in two formats: RStudio Desktop is a regular desktop application while RStudio Server runs on a remote server and allows accessing RStudio using a web browser.**

# %% [markdown]
# ####  2.What is a script?

# %% [markdown]
# **An R script is just a bunch of R code in a single file and can be written in any text editor, but saved with the .R suffix to make it clear that it contains R code.To write a new R script in RStudio, click File – New File – R Script.**

# %% [markdown]
# ####  3.What is a notebook?

# %% [markdown]
#    **The Notebook’s moveable code blocks and markdown cells enables exploratory data analysis, visualization, and collaboration. Notebook environments have a variety of supported Python libraries and R packages installed.It adds the results of output cells to reports, or share a link to the Notebook directly. When Notebook output is included in the Report, that Report’s schedule will re-run the Notebook so all of the data stays in sync.**
#
#  ** An R Notebook is an R Markdown document with chunks that can be executed independently and interactively, with output visible immediately beneath the input.A new notebook in RStudio is created  with the menu command File -> New File -> R Notebook.**

# %% [markdown]
# #### 4. Post a picture of the R studio screen and explain the different parts like the console

# %% [markdown]
# ![RStudio_Screen.png](attachment:RStudio_Screen.png)

# %% [markdown]
# ####  5.What is the difference between R Notebook - R Markdown - Jupyter Notebook

# %% [markdown]
#   **R Notebooks are a format maintained by RStudio, which develops and maintains a large number of open source R packages and tools, most notably the free-for-consumer RStudio R IDE.The primary difference is in the interativeness of an R Notebook where executing chunks in an R Markdown document, all the code is sent to the console at once, but in an R Notebook, only one line at a time is sent. This allows execution to stop if a line raises an error.Rmarkdown is based on markdown, a human readable markup language, Jupyter notebooks are based on JSON, a data interchange format common on the web. This means that Rmarkdown files can be easily edited using any text editor you like and the same is not true of Jupyter notebooks.**
#    **In Jupyter Notebooks, each block of Python input code executes in its own cell, and the output of the block appears inline; this allows the user to iterate on the results, both to make the data transformations explicit and to and make sure the results are as expected.In addition to code blocks, Jupyter Notebooks support Markdown cells, allowing for more detailed write-ups with easy formatting. The final Notebook can be exported as a HTML file displayable in a browser, or the raw Notebook file can be shared and rendered on sites like GitHub. Although Jupyter is a Python application, it can run kernels of non-Python languages, such as R.**

# %% [markdown]
# #### 6.Add any basic tips for those coding in R

# %% [markdown]
# #### All functions have help pages and its help page can be displayed by prefixing the function name with ?.
